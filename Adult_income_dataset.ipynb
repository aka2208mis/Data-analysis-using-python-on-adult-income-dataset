# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
data=pd.read_csv('/content/adult.csv')
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ## 1.) Display Top 10 rows in a Dataset.

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# ## 2.) Display last 10 rows of dataset.

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# ## 3.) Shape of dataset.

# %%
data.shape
# Out:
# (48842, 15)

# %%
print("number of rows",data.shape[0])
# Out:
# number of rows 48842

# %%
print("number of columns",data.shape[1])
# Out:
# number of columns 15

# %% [markdown]
# 4.) Getting information about dataset like total no of rows,no of columns,datatype of each columnand memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# 5.) Fetch Random samples from the dataset.

# %%
data=data.sample(frac=0.50,random_state=100)
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %% [markdown]
# 6.) Check null values in the dataset.

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# 7.) Perform data cleaning[Replace '?' with NaN.

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          1437
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1441
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      423
# income                0
# dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import numpy as np

# %%
data['occupation']=data['occupation'].replace('?',np.nan)
data['native-country']=data['native-country'].replace('?',np.nan)
data['workclass']=data['workclass'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          1437
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         1441
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      423
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# 8.) Drop all missing values.

# %%
per_missing=data.isnull().sum()*100/len(data)

# %%
per_missing
# Out:
# age                0.000000
# workclass          5.884280
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.900659
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.732116
# income             0.000000
# dtype: float64

# %%
data.dropna(how='any',inplace=True)
data.shape
# Out:
# (22582, 15)

# %%
32561-30162 #rows dropped
# Out:
# 2399

# %% [markdown]
# 9.) Check for duplicate data and drop them.

# %%
dup=data.duplicated().any()

# %%
print("Are there any duplicated values in data",dup)
# Out:
# Are there any duplicated values in data True

# %%
data.drop_duplicates()
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 42038   25    Private  312338     Assoc-voc               11
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship  \
# 12393  Married-civ-spouse     Other-service           Wife
# 48701       Never-married   Exec-managerial  Not-in-family
# ...

# %%
data.shape
# Out:
# (22582, 15)

# %% [markdown]
# 10.) Get overall statistics about dataframe.

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  22582.000000  2.258200e+04     22582.000000  22582.000000
# mean      38.621823  1.896294e+05        10.118103   1100.364450
# std       13.258239  1.061162e+05         2.553723   7554.672567
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173502e+05         9.000000      0.000000
# 50%       37.000000  1.778175e+05        10.000000      0.000000
# 75%       47.000000  2.377130e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  22582.000000    22582.000000
# mean      86.351342       40.897795
# std      400.831967       11.943793
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     3900.000000       99.000000

# %%
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   22582.000000     22582  2.258200e+04     22582     22582.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     16634           NaN      7341              NaN
# mean       38.621823       NaN  1.896294e+05       NaN        10.118103
# std        13.258239       NaN  1.061162e+05       NaN         2.553723
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173502e+05       NaN         9.000000
# 50%        37.000000       NaN  1.778175e+05       NaN        10.000000
# 75%        47.000000       NaN  2.377130e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['education'].unique()
# Out:
# array(['Prof-school', 'Bachelors', 'HS-grad', '9th', '10th', '12th',
#        'Masters', '7th-8th', 'Some-college', 'Assoc-voc', '5th-6th',
#        'Assoc-acdm', '11th', 'Doctorate', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
data['educational-num'].unique()
# Out:
# array([15, 13,  9,  5,  6,  8, 14,  4, 10, 11,  3, 12,  7, 16,  2,  1])

# %% [markdown]
# 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
dat=data.drop(['educational-num','capital-gain','capital-loss'],axis=1)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# Univariate Anlaysis
#
#
# 12.) What is the distribution of age column ?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    22582.000000
# mean        38.621823
# std         13.258239
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 13.) Find Total number of persons having age between 17 to 48(inclusive) using between method.

# %%
sum((data['age']>=17) & (data['age']<=48))
# Out:
# 17377

# %%
sum(data['age'].between(17,48))
# Out:
# 17377

# %% [markdown]
# 14) What is the distribution of workclass column ?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass'].describe()
# Out:
# count       22582
# unique          7
# top       Private
# freq        16634
# Name: workclass, dtype: object

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
data['workclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 15.) How many persons have Bachelors or masters degree ?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
filter1=data['education']=='Bachelors'
filter2=data['education']=='Masters'

# %%
len(data[filter1 | filter2])
# Out:
# 5025

# %%
sum(data['education'].isin(['Bachelors','Masters']))
# Out:
# 5025

# %% [markdown]
# 16.) Bivariate Analysis

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
import seaborn as sns
sns.boxplot(x='income',y='age',data=data)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# 17.) Replace Salary values between ['<=50K','>50K'] With 0 and 1.

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['income'].unique()
# Out:
# array(['>50K', '<=50K'], dtype=object)

# %%
data['income'].value_counts()
# Out:
# income
# <=50K    17001
# >50K      5581
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='income', data=data)
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
def salary_data(sal):
  if sal=='<=50K':
    return 0
  else:
    return 1

# %%
data['encoded_income'] = data['income'].apply(salary_data)

# %%
data.head(3)
# Out:
#        age workclass  fnlwgt    education  educational-num  \
# 12393   37   Private  110331  Prof-school               15
# 48701   23   Private   45834    Bachelors               13
# 17918   28   Private   89718      HS-grad                9
#
#            marital-status       occupation   relationship   race  gender  \
# 12393  Married-civ-spouse    Other-service           Wife  White  Female
# 48701       Never-married  Exec-managerial  Not-in-family  White  Female
# 17918       Never-married            Sales  Not-in-family  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income  \
# 12393             0             0              60  United-States   >50K
# 48701             0             0              50  United-States  <=50K
# 17918          2202             0              48  United-States  <=50K
#
#        encoded_income
# 12393               1
# 48701               0
# 17918               0

# %%
data.replace(to_replace=['<=50K','>50K'],value=[0,1],inplace=True)

# %%
data.head()
# Out:
#        age workclass  fnlwgt    education  educational-num  \
# 12393   37   Private  110331  Prof-school               15
# 48701   23   Private   45834    Bachelors               13
# 17918   28   Private   89718      HS-grad                9
# 11352   30   Private  351770          9th                5
# 36198   31   Private  164190         10th                6
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# 17918       Never-married             Sales  Not-in-family  White  Female
# 11352            Divorced     Other-service      Unmarried  White  Female
# 36198  Married-civ-spouse  Transport-moving        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income  \
# 12393             0             0              60  United-States       1
# ...

# %% [markdown]
# 18.) Which workclass getting the highest salary ?

# %%
data.groupby('workclass')['income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.563919
# Federal-gov         0.382482
# Local-gov           0.287001
# Self-emp-not-inc    0.278689
# State-gov           0.273760
# Private             0.216905
# Without-pay         0.076923
# Name: income, dtype: float64

# %% [markdown]
# 19.) Who has Better chance to get salary >50K Male or Female?

# %%
data.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.313042
# Female    0.111126
# Name: income, dtype: float64

# %% [markdown]
# 20.) Convert workclass columns datatypes to category datatypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22582 entries, 12393 to 32089
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              22582 non-null  int64
#  1   workclass        22582 non-null  object
#  2   fnlwgt           22582 non-null  int64
#  3   education        22582 non-null  object
#  4   educational-num  22582 non-null  int64
#  5   marital-status   22582 non-null  object
#  6   occupation       22582 non-null  object
#  7   relationship     22582 non-null  object
#  8   race             22582 non-null  object
#  9   gender           22582 non-null  object
#  10  capital-gain     22582 non-null  int64
#  11  capital-loss     22582 non-null  int64
#  12  hours-per-week   22582 non-null  int64
#  13  native-country   22582 non-null  object
#  14  income           22582 non-null  int64
#  15  encoded_income   22582 non-null  int64
# dtypes: int64(8), object(8)
# ...

# %%
data['workclass']=data['workclass'].astype('category')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22582 entries, 12393 to 32089
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              22582 non-null  int64
#  1   workclass        22582 non-null  category
#  2   fnlwgt           22582 non-null  int64
#  3   education        22582 non-null  object
#  4   educational-num  22582 non-null  int64
#  5   marital-status   22582 non-null  object
#  6   occupation       22582 non-null  object
#  7   relationship     22582 non-null  object
#  8   race             22582 non-null  object
#  9   gender           22582 non-null  object
#  10  capital-gain     22582 non-null  int64
#  11  capital-loss     22582 non-null  int64
#  12  hours-per-week   22582 non-null  int64
#  13  native-country   22582 non-null  object
#  14  income           22582 non-null  int64
#  15  encoded_income   22582 non-null  int64
# dtypes: category(1), int64(8), object(7)
# ...
